# %% [markdown]
# # Week03 : Linear Regression, Gradient Descent

# %% [markdown]
# - **Student ID** : 2021111000
# - **Name** : 조민준

# %% [markdown]
# - Write and run the code below (including Quiz) in jupyter notebook
# - After completion, rename the file, and summit the file to e-class
# - Submit file name : **“Week03_\<StudentID\>_\<Name\>.ipynb”**
#   - Ex) Week03\_2020123456\_홍길동.ipynb
# - Due : **Saturday 11:59pm**

# %% [markdown]
# ---

# %% [markdown]
# # 1. Linear regression by gradient descent

# %% [markdown]
# ### Sample dataset
# - Task: predicting $ x(size) \rightarrow y(price)$

# %%
import numpy as np
import matplotlib.pyplot as plt

# x_train is the vector of input variables (size in 1000 square feet)
# y_train is the vector of target values (price in 1000s of dollars)

x_train = np.array([1.8, 1.3, 1.7, 1.9, 1.4])
y_train = np.array([430., 320., 390., 490., 400.])

print('x_train =', x_train)
print('y_train =', y_train)
# Out:
# x_train = [1.8 1.3 1.7 1.9 1.4]
# y_train = [430. 320. 390. 490. 400.]

# %%
# plot the data points
None

plt.title("Housing Prices")
plt.ylabel('Price (1000 dollars)')
plt.xlabel('Size (1000 sqft)')
plt.show()

# %% [markdown]
# ### Prediction by a linear model
# - Model : $y = w x + b$

# %%
# Computes the prediction of a linear model
# w, b : model parameters  
# x, y : scalar 

def predict(x, w, b):

    # the linear model y = wx + b
    y = None
        
    return y

# %%
# predict with arbitrary model parameter 
w = 100
b = 10

print('size =     ', x_train[0])
print('price =    ', y_train[0])

# predict the y value of first data(x_train[0]) using w and b
y_hat = None

print('predicted =', y_hat)
# Out:
# size =      1.8
# price =     430.0
# predicted = 190.0

# %% [markdown]
# ### Cost function
# - Mean Squared Error
# ![image-4.png](attachment:image-4.png)

# %%
# Computes the cost function - MSE
# x is a vector of training data (ndarray (m,))

def compute_cost(x, y, w, b): 

    # number of training examples
    m = x.shape[0] 
    
    cost = 0   
    for i in range(m): 
        
        # compute the predicted y of each x by the linear model
        y_hat = None  
        
        # square (predicted y - true y), and add
        cost += None  
        
    cost = (1 / (2 * m)) * cost  
    return cost

# %%
print('w =', w)
print('b =', b)
print('y_train =', y_train)
print('y_hat =  ', predict(x_train, w, b))

# check the cost for the model with w = 100, b = 10
cost = None

print('--> cost =', cost)
# Out:
# w = 100
# b = 10
# y_train = [430. 320. 390. 490. 400.]
# y_hat =   [190. 140. 180. 200. 150.]
# --> cost = 28070.0

# %% [markdown]
# ### Computing gradients
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %%
# Compute the gradient for linear regression 
# x is a vector of training data (ndarray (m,))
# dj_dw : The gradient of the cost w.r.t. the parameters w
# dj_db : The gradient of the cost w.r.t. the parameter b     

def compute_gradient(x, y, w, b): 
    
    # Number of training examples
    m = x.shape[0]  
    
    dj_dw = 0
    dj_db = 0
    
    for i in range(m):  
        # compute the predicted y 
        y_hat = None 
        
        # compute the gradients
        dj_dw += None 
        dj_db += None

    dj_dw = dj_dw / m 
    dj_db = dj_db / m 
        
    return dj_dw, dj_db

# %%
# check the gradients for current w, b
print('w =', w)
print('b =', b)
print('x_train =', x_train)
print('y_train =', y_train)

dj_dw, dj_db = None

print('dj_dw =', dj_dw)
print('dj_db =', dj_db)
# Out:
# w = 100
# b = 10
# x_train = [1.8 1.3 1.7 1.9 1.4]
# y_train = [430. 320. 390. 490. 400.]
# dj_dw = -384.8
# dj_db = -234.0

# %% [markdown]
# ### Gradient descent
# - Repeat ![image-2.png](attachment:image-2.png)

# %%
# Performs gradient descent to fit w, b

def gradient_descent(x, y, w, b, alpha, num_iters): 
    """  
    x (ndarray (m,))  : data, m examples 
    y (ndarray (m,))  : target values
    alpha (float)     : learning rate
    num_iters (int)   : number of iterations

    J_history (list)  : History of cost values
    """
    J_history = []
    
    for i in range(num_iters):
        # compute the gradient 
        dj_dw, dj_db = None     

        # update Parameters 
        w = None                            
        b = None                            

        # save cost to J_history list 
        J_history.append(None)

        # print cost every 1000 iteration  
        if (i % 1000) == 0:
            print('Iteration %5d: Cost %0.2e ' % (i, J_history[-1]))
           
    return w, b, J_history

# %% [markdown]
# ### Linear regression by gradient descent
# - Starting from initial parameters
# - Use GD to get the parameters

# %%
# initialize parameters
w_init = 0
b_init = 0

# set the hyper parameters, 0.01 and 10000
alpha = None
iterations = None

# run gradient descent
w_final, b_final, J_hist = None

# print the learned parameters
None
None
# Out:
# Iteration     0: Cost 7.79e+04
# Iteration  1000: Cost 3.99e+02
# Iteration  2000: Cost 3.96e+02
# Iteration  3000: Cost 3.93e+02
# Iteration  4000: Cost 3.92e+02
# Iteration  5000: Cost 3.90e+02
# Iteration  6000: Cost 3.90e+02
# Iteration  7000: Cost 3.89e+02
# Iteration  8000: Cost 3.88e+02
# Iteration  9000: Cost 3.88e+02
# w = 201.1031304050341
# b = 80.34795484298294

# %% [markdown]
# ### Plotting cost change

# %%
# plot cost during iteration 1 ~ 100 
None

plt.title("Cost vs. Iteration")
plt.ylabel('cost') 
plt.xlabel('iteration')  
plt.show()

# %% [markdown]
# ### Plotting the learned model

# %%
# plot the data points
plt.scatter(x_train, y_train, marker='o', c='blue')

# predict the y value for x_train using learned w and b
y_hat = None

# show the model by plotting x_train and y_hat
None  

plt.title('SIZE vs. PRICE') 
plt.xlabel('size') 
plt.ylabel('price') 
plt.grid()
plt.show()

# %%
# test price prediction for 1.5 thousand sqft house
size = 1.5
price = None

print('Prediction: %.2f sqft house --> %.2f thousand dollars' % (size*1000, price))
# Out:
# Prediction: 1500.00 sqft house --> 382.00 thousand dollars

# %% [markdown]
# ---

# %% [markdown]
# # 2. Linear Regression by gradient descent - multiple variables, vector form

# %% [markdown]
# ### Sample dataset
# - Task: predicting $ x_{0}(size), x_{1}(rooms) \rightarrow y(price)$
# - Be careful! the name of dataset is X_train, not x_train!

# %%
import numpy as np
import matplotlib.pyplot as plt

# X_train is the vector of input variables (size in 1000 square feet, number of rooms)
# y_train is the vector of target values (price in 1000s of dollars)

X_train = np.array([[1.8, 4], [1.3, 3], [1.7, 4], [1.9, 5], [1.4, 3]])
y_train = np.array([430., 320., 390., 490., 400.])

print(X_train)
print(y_train)
# Out:
# [[1.8 4. ]
#  [1.3 3. ]
#  [1.7 4. ]
#  [1.9 5. ]
#  [1.4 3. ]]
# [430. 320. 390. 490. 400.]

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# plot the data points in 3D
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='blue')
plt.show()

# %% [markdown]
# ### Prediction by a linear model
# - Model : $ y = \mathbf{x \cdot w} + b = w_{0} x_{0} + w_{1} x_{1} + b $

# %%
# Compute the prediction of a linear model
# x : array (m, n) - m examples with n features
# y : vector (m, ) 
# w : model parameters (n, )
# b : model parameter scalar 

def predict(x, w, b): 

    # the linear model y = wx + b
    y = None    
    
    return y

# %% [markdown]
# - Prediction - single data
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
# arbitrary model parameter 
w = np.array([100, 100])
b = 10

# first row from training data
print('X_train[0] =', X_train[0])
print('y_train[0] =', y_train[0])

# predict the y value of first data(X_train[0]) using w and b
y_hat = None

print('y_hat =     ', y_hat)
# Out:
# X_train[0] = [1.8 4. ]
# y_train[0] = 430.0
# y_hat =      590.0

# %% [markdown]
# - Prediction - all data
# ![image-2.png](attachment:image-2.png)
# - Vector form
# ![image-3.png](attachment:image-3.png)

# %%
w = np.array([100, 100])
b = 10

# all training data
print('X_train =', X_train)
print('y_train =', y_train)

# predict the y values of all data(X_train) using w and b
y_hat = None

print('y_hat =  ', y_hat)
# Out:
# X_train = [[1.8 4. ]
#  [1.3 3. ]
#  [1.7 4. ]
#  [1.9 5. ]
#  [1.4 3. ]]
# y_train = [430. 320. 390. 490. 400.]
# y_hat =   [590. 440. 580. 700. 450.]

# %% [markdown]
# ### Cost function
# ![image-4.png](attachment:image-4.png)
# - Vector form ![image-7.png](attachment:image-7.png)

# %%
# Computes the cost function - MSE

def compute_cost(X, y, w, b): 
    """
      X (ndarray (m,n)): dataset, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters  
      b (scalar)       : model parameter
    """
    # number of training examples and number of features
    m, n = X.shape

    # compute y_hat
    y_hat = None
    
    # compute the cost
    cost = None

    return cost

# %%
print('w =', w)
print('b =', b)
print('y_train =', y_train)
print('y_hat =  ', predict(X_train, w, b))

# check the cost for the model with w = [100, 100], b = 10
cost = None

print('--> cost =', cost)
# Out:
# w = [100 100]
# b = 10
# y_train = [430. 320. 390. 490. 400.]
# y_hat =   [590. 440. 580. 700. 450.]
# --> cost = 12270.0

# %% [markdown]
# ### Computing gradients
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# - Vector form
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)

# %%
# Computes the gradient for linear regression 

def compute_gradient(X, y, w, b): 
    """
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters  
      b (scalar)       : model parameter
      
      dj_dw (ndarray (n,)): The gradient of the cost w.r.t. the parameters w. 
      dj_db (scalar):       The gradient of the cost w.r.t. the parameter b. 
    """
    # number of training examples and number of features
    m, n = X.shape           
    
    dj_dw = np.zeros((n,))
    dj_db = 0.
    
    # compute y_hat
    y_hat = None
    err = y_hat - y   
    
    # compute gradients
    dj_dw = None
    dj_db = None
       
    return dj_dw, dj_db

# %%
# check the gradients for current w, b
print('w =', w)
print('b =', b)
print('X_train =', X_train)
print('y_train =', y_train)

dj_dw, dj_db = None

print('dj_dw =', dj_dw)
print('dj_db =', dj_db)
# Out:
# w = [100 100]
# b = 10
# X_train = [[1.8 4. ]
#  [1.3 3. ]
#  [1.7 4. ]
#  [1.9 5. ]
#  [1.4 3. ]]
# y_train = [430. 320. 390. 490. 400.]
# dj_dw = [247.2 592. ]
# dj_db = 146.0

# %% [markdown]
# ### Gradient descent
# - Repeat ![image-3.png](attachment:image-3.png)

# %%
# Performs gradient descent to fit w, b

def gradient_descent(X, y, w, b, alpha, num_iters): 
    """
      X (ndarray (m,n))   : data, m examples with n features
      y (ndarray (m,))    : target values
      w (ndarray (n,)): model parameters  
      b (scalar)      : model parameter
      alpha (float)       : learning rate
      num_iters (int)     : number of iterations 
    """
    # a list to store cost J at each iteration
    J_history = []
    
    for i in range(num_iters):

        # compute the gradient 
        dj_dw, dj_db = None   

        # update Parameters 
        w = None              
        b = None              
      
        # save cost to J_history list 
        J_history.append(None)

        # print cost every 1000 iteration
        if (i % 1000) == 0:
            print('Iteration %5d: Cost %0.2e ' % (i, J_history[-1]))
        
    return w, b, J_history

# %% [markdown]
# ### Linear regression by gradient descent
# - Starting from initial parameters
# - Use GD to get the parameters

# %%
# initialize parameters
w_init = np.zeros(X_train.shape[1])
b_init = 0.

# set the hyperparameters, 0.1 and 10000
alpha = None
iterations = None

# run gradient descent
w_final, b_final, J_hist = None

# print the learned parameters
None
None
# Out:
# Iteration     0: Cost 6.27e+04
# Iteration  1000: Cost 3.76e+02
# Iteration  2000: Cost 3.74e+02
# Iteration  3000: Cost 3.73e+02
# Iteration  4000: Cost 3.73e+02
# Iteration  5000: Cost 3.72e+02
# Iteration  6000: Cost 3.72e+02
# Iteration  7000: Cost 3.72e+02
# Iteration  8000: Cost 3.72e+02
# Iteration  9000: Cost 3.72e+02
# w = [137.51483137  22.57217992]
# b = 97.45385409256511

# %% [markdown]
# ### Plotting cost change

# %%
# plot cost during iteration 1 ~ 100 
None

plt.title("Cost vs. Iteration")
plt.ylabel('cost') 
plt.xlabel('iteration')  
plt.show()

# %% [markdown]
# ### Plotting the learned model

# %%
from matplotlib import cm

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# plot the data points
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='blue')

# predict the y values for all meshgrid using learned w and b
x0 = np.arange(1, 2, 0.1)
x1 = np.arange(2, 6, 0.1)
x0, x1 = np.meshgrid(x0, x1)
y_hat = None

# show the model by plotting Z surface
ax.plot_surface(x0, x1, y_hat, cmap=cm.coolwarm, alpha=0.5)

plt.show()

# %%
from sklearn.metrics import mean_squared_error

# compute y_hat for X_train
y_hat = None 

# print the mean squared error(MSE) between y and y_hat 
print('MSE : %.2f' % mean_squared_error(y_train, y_hat))
# Out:
# MSE : 744.62

# %% [markdown]
# # 3. Linear Regression using scikit learn

# %%
X_train = np.array([[1.8, 4], [1.3, 3], [1.7, 4], [1.9, 5], [1.4, 3]])
y_train = np.array([430., 320., 390., 490., 400.])

print(X_train)
print(y_train)
# Out:
# [[1.8 4. ]
#  [1.3 3. ]
#  [1.7 4. ]
#  [1.9 5. ]
#  [1.4 3. ]]
# [430. 320. 390. 490. 400.]

# %%
from sklearn.linear_model import LinearRegression

# training the model - use .fit()
lr = None
None
# Out:
# LinearRegression()

# %%
# print the learned model parameters
None
None
# Out:
# w =  [138.46153846  22.30769231]
# b =  96.92307692307696

# %%
from sklearn.metrics import mean_squared_error

# predict y values for X - use .predict()
y_hat = None

# print the mean squared error(MSE) between y and y_hat 
print('MSE : %.2f' % mean_squared_error(y_train, y_hat))
# Out:
# MSE : 744.62

# %% [markdown]
# # 4. Polynomial Regression and Regularization

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

def true_fun(X):
    return np.cos(1.5*np.pi * X)

# sample data. 
np.random.seed(0)
n_samples = 20
X = np.sort(np.random.rand(n_samples))
y = true_fun(X) + np.random.randn(n_samples) * 0.1

X = X.reshape(-1, 1)
print(X[:3])
print(y[:3])
# Out:
# [[0.0202184 ]
#  [0.07103606]
#  [0.0871293 ]]
# [1.14487249 0.9239768  0.94819339]

# %%
# plot the data points
plt.scatter(X, y, edgecolor="b", s=20)

plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
# training the linear regression model with X
lr = None
None

plt.scatter(X, y, edgecolor="b", s=20)

# show the model by plotting x_test and predicted values
X_test = np.arange(0, 1, 0.1).reshape(-1, 1)
None

plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ### Generating polynomial features
# - $x \rightarrow x, x^2, x^3, ...$

# %%
from sklearn.preprocessing import PolynomialFeatures

# generate polynomial features of X. degree=10 
poly = PolynomialFeatures(degree=10, include_bias=False)
X_poly = poly.fit_transform(X)

print(X_poly[:3])
# Out:
# [[2.02183974e-02 4.08783595e-04 8.26494919e-06 1.67104028e-07
#   3.37857564e-09 6.83093851e-11 1.38110630e-12 2.79237560e-14
#   5.64573598e-16 1.14147734e-17]
#  [7.10360582e-02 5.04612156e-03 3.58456585e-04 2.54633428e-05
#   1.80881550e-06 1.28491123e-07 9.12750292e-09 6.48381829e-10
#   4.60584893e-11 3.27181353e-12]
#  [8.71292997e-02 7.59151487e-03 6.61443374e-04 5.76310980e-05
#   5.02135721e-06 4.37507337e-07 3.81197079e-08 3.32134345e-09
#   2.89386329e-10 2.52140282e-11]]

# %% [markdown]
# ### Polynomial regression
# - $y = w_{0}x^0 + w_{1}x^1 + w_{2}x^2 + ...$
# - $cost = ||y - Xw||^2_2  $

# %%
# training the linear regression model with polynomial features of X
lr = None
None

plt.scatter(X, y, edgecolor="b", s=20)

X_test = np.arange(0, 1, 0.01).reshape(-1, 1)
# generate polynomial features of X_test 
X_test_poly = poly.fit_transform(X_test)

# show the model by plotting X_test and predicted values from polynomial features of X_test
None

plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ### Polynomial regression with regularization
# - $cost = ||y - Xw||^2_2 + \alpha * ||w||^2_2 $

# %%
# training the ridge regression model with polynomial features of X
# set regularization parameter alpha = 0.01 
lr = None
None

plt.scatter(X, y, edgecolor="b", s=20)

X_test = np.arange(0, 1, 0.01).reshape(-1, 1)
# generate polynomial features of X_test 
X_test_poly = poly.fit_transform(X_test)

# show the model by plotting X_test and predicted values from polynomial features of X_test
None

plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Quiz 1 : Linear Regression - Gradient descent
#
# ## Find a model predicting 'MEDV' from 'LSTAT' using Boston Housing Dataset
# - Train linear regression model using gradient descent with X = 'MEDV'(Median value) and y = 'LSTAT'(lower status of population %)
#   - Use the functions from 2. Linear Regression by gradient descent - multiple variables, vector form
# - Show the learned model (parameters)
# - Show the cost change during learning
# - Compute the Mean Squared Error of the model
# - Plot the model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("housing_data.txt", header=None, sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 
              'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# plotting number of lower status(LSTAT) vs. price(MEDV) 
plt.scatter(df["LSTAT"].values, df["MEDV"].values, c="steelblue", edgecolor="white", s=70)

plt.title('LSTAT vs MEDV') 
plt.xlabel('Lower status %') 
plt.ylabel('Price') 
plt.grid()
plt.show()

# %%
# get X, y array from df's LSTAT, MEDV column - use .values
X = df["LSTAT"].values.reshape(-1, 1)
y = df["MEDV"].values

# show X, y and shapes
X = X.reshape(-1, 1)
print(X[0:3])
print(X.shape)
print(y[0:3])
print(y.shape)
# Out:
# [[4.98]
#  [9.14]
#  [4.03]]
# (506, 1)
# [24.  21.6 34.7]
# (506,)

# %%
# use the functions from 2. Linear Regression by gradient descent - multiple variables, vector form
# compute_cost, compute_gradient, gradient_descent

# 비용 함수
def compute_cost(X, y, w, b):
    m = len(y)
    cost = np.sum(((X.dot(w) + b) - y) ** 2) / (2 * m)
    return cost

# 경사 계산 함수
def compute_gradient(X, y, w, b):
    m = len(y)
    dj_dw = np.dot(X.T, (np.dot(X, w) + b - y)) / m
    dj_db = np.sum(np.dot(X, w) + b - y) / m
    return dj_dw, dj_db

# 경사 하강 함수
def gradient_descent(X, y, w, b, alpha, num_iters):
    cost_history = []
    for i in range(num_iters):
        dj_dw, dj_db = compute_gradient(X, y, w, b)
        w = w - alpha * dj_dw
        b = b - alpha * dj_db
        cost_history.append(compute_cost(X, y, w, b))
    return w, b, cost_history

# %%
# initialize parameters to zero
#   -0.31980217  0.29787681 -0.4517336  -0.31980217 -0.27782399 -0.37377412
#   -0.93148427 -0.9194905  -0.90149985 -0.72759023 -0.82354037 -0.8475279
#   -0.34978659 -0.49970867 -0.10391437 -0.54768374 -0.64963075 -0.85352478
#   -0.739584   -0.69760582 -0.69160893 -0.78156218 -0.48171802 -0.50570555
#   -0.38576789 -0.49371179 -0.64963075 -0.54768374 -0.7755653  -0.82953725
#   -0.8475279  -0.58366504 -0.72159335 -0.32579905 -0.24783957 -0.42774607
#   -0.7036027  -0.64363387 -0.45773049 -0.5956588  -0.50570555 -0.57167127
#   -0.54768374 -0.43973984 -0.38576789 -0.28382087 -0.45773049 -0.50570555
#   -0.58966192 -0.54168685 -0.45773049 -0.15188944 -0.36777724 -0.28981775
#   -0.18187386 -0.13989567 -0.06793307 -0.15788632 -0.21185827 -0.20586139
#   -0.20586139 -0.14589256 -0.15788632 -0.17587697  0.04001083  0.43580512
#   -0.5236962  -0.55368062 -0.34978659 -0.6316401  -0.47572114 -0.06793307
#    0.02801706  0.06999524  0.14795473 -0.04394554 -0.11590814 -0.07992684
#   -0.20586139 -0.11590814 -0.43973984 -0.93148427 -0.86551855 -0.53568997
#   -0.14589256 -0.04394554  0.11797031  0.03401394 -0.16988009 -0.25383645
#   -0.07992684 -0.30181152 -0.3437897  -0.00796424 -0.11590814  0.08198901
#   -0.03195177 -0.63763699]]
# b = 22.532806324110652

# %%
# plot cost during iteration 1 ~ 100 
plt.plot(range(1, num_iters + 1), cost_history, color='blue')
plt.title('Cost vs. iterations')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.grid()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8 ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.metrics import mean_squared_error

y_hat = X.dot(w_final) + b_final
mse = mean_squared_error(y, y_hat)
print('MSE =', mse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 4
#       1 from sklearn.metrics import mean_squared_error
#       3 y_hat = X.dot(w_final) + b_final
# ----> 4 mse = mean_squared_error(y, y_hat)
#       5 print('MSE =', mse)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#     445     check_consistent_length(y_true, y_pred, sample_weight)
#     446     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:111, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     108     y_pred = y_pred.reshape((-1, 1))
#     110 if y_true.shape[1] != y_pred.shape[1]:
# --> 111     raise ValueError(
#     112         "y_true and y_pred have different number of output ({0}!={1})".format(
#     113             y_true.shape[1], y_pred.shape[1]
#     114         )
#     115     )
#     117 n_outputs = y_true.shape[1]
#     118 allowed_multioutput_str = ("raw_values", "uniform_average", "variance_weighted")
#
# ValueError: y_true and y_pred have different number of output (1!=506)

# %%
# plotting the data and model 
plt.scatter(X, y, c="steelblue", edgecolor="white", s=70)
plt.plot(X, y_hat, color='red', linewidth=2)
plt.title('LSTAT vs PRICES') 
plt.xlabel('Lower status %') 
plt.ylabel('Price') 
plt.grid()
plt.show()

# %% [markdown]
# # Quiz 2 : Linear Regression - Scikit learn
#
# ## Find a model predicting 'MEDV' from 'LSTAT' using Boston Housing Dataset
# - Train linear regression model using scikit learn with X = 'MEDV'(Median value) and y = 'LSTAT'(lower status of population %)
# - Show the learned model (parameters)
# - Compute the Mean Squared Error of the model
# - Plot the model

# %%
print(X[0:3])
print(X.shape)
print(y[0:3])
print(y.shape)
# Out:
# [[4.98]
#  [9.14]
#  [4.03]]
# (506, 1)
# [24.  21.6 34.7]
# (506,)

# %%
from sklearn.linear_model import LinearRegression

# training the linear regression model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# print the learned model parameters
print(f"Model slope (w): {model.coef_[0]}")
print(f"Model intercept (b): {model.intercept_}")
# Out:
# Model slope (w): -0.9500493537579914
# Model intercept (b): 34.55384087938312

# %%
from sklearn.metrics import mean_squared_error

# predict y values for X - use .predict()
y_pred = model.predict(X)

# print the mean squared error(MSE) 
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Mean Squared Error (MSE): 38.48296722989414

# %%
# plotting the data and model 
plt.scatter(X, y, color='steelblue', edgecolor='white', s=70)
plt.plot(X, y_pred, color='red', linewidth=2)  

plt.title('LSTAT vs MEDV') 
plt.xlabel('Lower status %') 
plt.ylabel('Price') 
plt.grid()
plt.show()

# %% [markdown]
# # Quiz 3: Polynomial Regression - Scikit learn
#
# ## Find a model predicting 'MEDV' from 'LSTAT' using Boston Housing Dataset
# - Train linear regression model using scikit learn with X = 'MEDV'(Median value) and y = 'LSTAT'(lower status of population %)
# - Use PolynomialFeatures of degree=2 to generate ($x$, $x^2$)
# - Show the learned model (parameters)
# - Compute the Mean Squared Error of the model
# - Plot the model

# %%
from sklearn.preprocessing import PolynomialFeatures

# generate polynomial features of X. degree=2 
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

print(X_poly[:3])
print(X_poly.shape)
# Out:
# [[ 1.      4.98   24.8004]
#  [ 1.      9.14   83.5396]
#  [ 1.      4.03   16.2409]]
# (506, 3)

# %%
from sklearn.linear_model import LinearRegression

# training the linear regression model with polynomial features of X
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# print the learned model parameters
print(f"Model coefficients: {model.coef_}")
print(f"Model intercept: {model.intercept_}")
# Out:
# Model coefficients: [ 0.         -2.3328211   0.04354689]
# Model intercept: 42.862007328169284

# %%
from sklearn.metrics import mean_squared_error

# predict y values for X - use .predict()
y_pred = model.predict(X_poly)

# print the mean squared error(MSE) 
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Mean Squared Error (MSE): 30.330520075853713

# %%
# plotting the data  
plt.scatter(X, y, color='steelblue', edgecolor='white', s=70)
  

# show the model by plotting X_test and predicted values from polynomial features of X_test
X_test = np.arange(0, 40, 0.01).reshape(-1, 1)
X_test_poly = poly.transform(X_test)
y_test_pred = model.predict(X_test_poly)
plt.plot(X_test, y_test_pred, color='red', linewidth=2)

plt.title('LSTAT vs MEDV') 
plt.xlabel('Lower status %') 
plt.ylabel('Price') 
plt.grid()
plt.show()
